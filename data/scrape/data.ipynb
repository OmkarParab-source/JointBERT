# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import numpy as np
import pandas as pd
import random

# %%
data = pd.read_csv('appData.csv')
data = data['apps']
data.head()
# Out:
# 0               Xara Designer Pro
# 1          Free Reverse GIF Maker
# 2    Wolfenstein: Enemy Territory
# 3                         F1 2012
# 4             Scions of Fate Demo
# Name: apps, dtype: object

# %%
data
# Out:
# 0                               Xara Designer Pro
# 1                          Free Reverse GIF Maker
# 2                    Wolfenstein: Enemy Territory
# 3                                         F1 2012
# 4                             Scions of Fate Demo
#                           ...
# 2282    Unlimited Free VPN - Betternet for Chrome
# 2283                     Zombie Apocalypse Racing
# 2284                                   ScreenGrab
# 2285     RAPTOR - Flowchart Interpreter fall-2014
# 2286                        Baking Simulator Demo
# Name: apps, Length: 2287, dtype: object

# %%
rng = np.random.RandomState()
print(data.shape)
data1 = data.sample(frac=0.3, random_state=rng)
print(data1.shape)
remaining = data.loc[~data.index.isin(data1.index)]
remaining = remaining.reset_index(drop=True)
remaining.head()
data2 = remaining.sample(frac=0.5, random_state=rng)
print(data2.shape)
data3 = remaining.loc[~remaining.index.isin(data2.index)]
print(data3.shape)
# Out:
# (2287,)
# (686,)
# (800,)
# (801,)

# %%
exts = pd.read_csv("exts.csv")
exts = exts["extensions"]
exts.head()
# Out:
# 0    wpd
# 1    txt
# 2    tex
# 3    rtf
# 4    pdf
# Name: extensions, dtype: object

# %%
intents = [
    "OpenEntity",
    "CloseEntity",
    "DeleteEntity",
    "MoveEntity",
    "RenameEntity",
    "AddToArchive",
    "SelectEntity",
    "SearchEntity",
    "ListDir",
    "AddToNotes",
    "SearchTopic",
    "SendEmail",
    "Weather",
]

slots = [
    ["B-object_name", "I-object_name"],
    ["B-note", "I-note"],
    ["B-object_type", "I-object_type"],
    ["B-dirname", "I-dirname"],
    ["B-from_dirname", "I-from_dirname"],
    ["B-to_dirname", "I-to_dirname"],
    ["B-entity_name", "I-entity_name"],
    ["B-positional", "I-positional"],
    ["B-timeRange", "I-timeRange"],
    ["B-source", "I-source"],
    ["B-recipient", "I-recipient"],
    ["B-subject", "I-subject"],
    ["B-location_name", "I-location_name"],
    ["B-weather-condition", "I-weather-condition"],
]

filler = [
    list(data1),
    ["to send mail to", "to talk to", "to make changes to", "to wash the", "to take out the", "to complete", "to clear it", "to open the thing", "to wash the mirrors", "to delete the", "to take my meds", "open command", "delete the file"],
    list(exts),
    list(data2),
    list(data2),
    list(data2),
    list(data3),
    ["first", "second", "third", "fourth", "fifth", "sixth", "seventh", "eighth", "nineth","last"],
    [],
    ["wikipedia", "youtube", "google"],
    ["Ava Barker", "Caldwell Wagner", "Bianca Poe", "Grant Baldwin", "Morton Abbott", "Camille Estrada", "Estelle Andrus", "Stuart Woolridge"],
    ["submission of files", "send the report", "customer review", "anything"],
    ["Mumbai", "Banglore", "Delhi", "Dahanu", "Kashmir", "Kandivali", "Churchgate", "India"],
]

# %%
def open_example():
    intent = "OpenEntity"
    slot1 = random.choice(filler[0])
    slot2 = random.choice(filler[3])
    input = "open %s from %s folder"%(slot1, slot2)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-object_name")
            count = count+1
        else:
            slot1_out.append("I-object_name")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-dirname")
            count = count+1
        else:
            slot2_out.append("I-dirname")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.append("0")
    output_list.extend(slot2_out)
    output_list.append("0")
    output = " ".join(output_list)
    return input, output, intent

# %%
def delete_example():
    intent = "DeleteEntity"
    slot1 = random.choice(filler[0])
    slot2 = random.choice(filler[3])
    input = "delete %s from %s folder"%(slot1, slot2)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-object_name")
            count = count+1
        else:
            slot1_out.append("I-object_name")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-dirname")
            count = count+1
        else:
            slot2_out.append("I-dirname")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.append("0")
    output_list.extend(slot2_out)
    output_list.append("0")
    output = " ".join(output_list)
    return input, output, intent

# %%
def close_example():
    intent = "CloseEntity"
    slot1 = random.choice(filler[0])
    input = "close %s"%(slot1)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-object_name")
            count = count+1
        else:
            slot1_out.append("I-object_name")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
def open_positional_example():
    intent = "OpenEntity"
    slot1 = random.choice(filler[7])
    slot2 = random.choice(filler[2])
    slot3 = random.choice(filler[3])
    input = "open %s %s from %s folder"%(slot1, slot2, slot3)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-positional")
            count = count+1
        else:
            slot1_out.append("I-positional")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-object_type")
            count = count+1
        else:
            slot2_out.append("I-object_type")
    count = 0
    slot3_out = []
    for word in slot3.split():
        if count == 0:
            slot3_out.append("B-dirname")
            count = count+1
        else:
            slot3_out.append("I-dirname")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.extend(slot2_out)
    output_list.append("0")
    output_list.extend(slot3_out)
    output_list.append("0")
    output = " ".join(output_list)
    return input, output, intent

# %%
def delete_positional_example():
    intent = "DeleteEntity"
    slot1 = random.choice(filler[7])
    slot2 = random.choice(filler[2])
    slot3 = random.choice(filler[3])
    input = "delete %s %s from %s folder"%(slot1, slot2, slot3)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-positional")
            count = count+1
        else:
            slot1_out.append("I-positional")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-object_type")
            count = count+1
        else:
            slot2_out.append("I-object_type")
    count = 0
    slot3_out = []
    for word in slot3.split():
        if count == 0:
            slot3_out.append("B-dirname")
            count = count+1
        else:
            slot3_out.append("I-dirname")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.extend(slot2_out)
    output_list.append("0")
    output_list.extend(slot3_out)
    output_list.append("0")
    output = " ".join(output_list)
    return input, output, intent

# %%
def remind_me():
    intent = "AddToNotes"
    slot1 = random.choice(filler[1])
    slot2 = random.choice(filler[0])
    input = "Remind me %s %s"%(slot1, slot2)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-note")
            count = count+1
        else:
            slot1_out.append("I-note")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-entity_name")
            count = count+1
        else:
            slot2_out.append("I-entity_name")
    output_list = []
    output_list.append("0")
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.extend(slot2_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
def add_reminder():
    intent = "AddToNotes"
    slot1 = random.choice(filler[1])
    input = "Add reminder for %s"%(slot1)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-note")
            count = count+1
        else:
            slot1_out.append("I-note")
    output_list = []
    output_list.append("0")
    output_list.append("0")
    output_list.append("0")
    output_list.extend(slot1_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
def select_example():
    intent = "SelectEntity"
    slot1 = random.choice(filler[0])
    input = "select %s"%(slot1)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-object_name")
            count = count+1
        else:
            slot1_out.append("I-object_name")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
def select_positional_example():
    intent = "SelectEntity"
    slot1 = random.choice(filler[7])
    slot2 = random.choice(filler[2])
    input = "select %s %s"%(slot1, slot2)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-positional")
            count = count+1
        else:
            slot1_out.append("I-positional")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-object_type")
            count = count+1
        else:
            slot2_out.append("I-object_type")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.extend(slot2_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
def move_object_to_from():
    intent = "MoveEntity"
    slot1 = random.choice(filler[0])
    slot2 = random.choice(filler[3])
    slot3 = random.choice(filler[4])
    input = "move %s to %s from %s folder"%(slot1, slot2, slot3)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-object_name")
            count = count+1
        else:
            slot1_out.append("I-object_name")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-to_dirname")
            count = count+1
        else:
            slot2_out.append("I-to_dirname")
    count = 0
    slot3_out = []
    for word in slot3.split():
        if count == 0:
            slot3_out.append("B-from_dirname")
            count = count+1
        else:
            slot3_out.append("I-from_dirname")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.append("0")
    output_list.extend(slot2_out)
    output_list.append("0")
    output_list.extend(slot3_out)
    output_list.append("0")
    output = " ".join(output_list)
    return input, output, intent

# %%
def move_object_from_to():
    intent = "MoveEntity"
    slot1 = random.choice(filler[0])
    slot2 = random.choice(filler[3])
    slot3 = random.choice(filler[4])
    input = "move %s from %s to %s folder"%(slot1, slot2, slot3)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-object_name")
            count = count+1
        else:
            slot1_out.append("I-object_name")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-from_dirname")
            count = count+1
        else:
            slot2_out.append("I-from_dirname")
    count = 0
    slot3_out = []
    for word in slot3.split():
        if count == 0:
            slot3_out.append("B-to_dirname")
            count = count+1
        else:
            slot3_out.append("I-to_dirname")
    output_list = []
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.append("0")
    output_list.extend(slot2_out)
    output_list.append("0")
    output_list.extend(slot3_out)
    output_list.append("0")
    output = " ".join(output_list)
    return input, output, intent

# %%
def send_email_to_about():
    intent = "SendEmail"
    slot1 = random.choice(filler[10])
    slot2 = random.choice(filler[11])
    input = "send an email to %s about %s"%(slot1, slot2)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-recipient")
            count = count+1
        else:
            slot1_out.append("I-recipient")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-subject")
            count = count+1
        else:
            slot2_out.append("I-subject")
    output_list = []
    output_list.append("0")
    output_list.append("0")
    output_list.append("0")
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.append("0")
    output_list.extend(slot2_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
def send_email():
    intent = "SendEmail"
    input = "send an email"
    count = 0
    output_list = []
    output_list.append("0")
    output_list.append("0")
    output_list.append("0")
    output = " ".join(output_list)
    return input, output, intent

# %%
def weather():
    intent = "GetWeather"
    slot1 = random.choice(filler[12])
    input = "tell the weather in %s"%(slot1)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-location_name")
            count = count+1
        else:
            slot1_out.append("I-location_name")
    output_list = []
    output_list.append("0")
    output_list.append("0")
    output_list.append("0")
    output_list.append("0")
    output_list.extend(slot1_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
def search_topic():
    intent = "SearchEntity"
    slot1 = random.choice(filler[0])
    slot2 = random.choice(filler[9])
    input = "search for %s on %s"%(slot1, slot2)
    count = 0
    slot1_out = []
    for word in slot1.split():
        if count == 0:
            slot1_out.append("B-object_name")
            count = count+1
        else:
            slot1_out.append("I-object_name")
    count = 0
    slot2_out = []
    for word in slot2.split():
        if count == 0:
            slot2_out.append("B-dirname")
            count = count+1
        else:
            slot2_out.append("I-dirname")
    output_list = []
    output_list.append("0")
    output_list.append("0")
    output_list.extend(slot1_out)
    output_list.append("0")
    output_list.extend(slot2_out)
    output = " ".join(output_list)
    return input, output, intent

# %%
input, output, intent = search_topic()
print(input)
print(output)
print(intent)
# Out:
# search for Style XP on youtube
# 0 0 B-object_name I-object_name 0 B-dirname
# SearchEntity

# %%
command_functions = [
    open_example,
    open_positional_example,
    delete_example,
    delete_positional_example,
    close_example,
    remind_me,
    add_reminder,
    select_example,
    select_positional_example,
    move_object_from_to,
    move_object_to_from,
    send_email_to_about,
    send_email,
    weather,
    search_topic,
]

# %%
np.random.seed(39209)

inputfile = open("seq.in", "a", encoding="utf-8")
outputfile = open("seq.out", "a", encoding="utf-8")
labelfile = open("label", "a", encoding="utf-8")

for _ in range(1, 700):
    input, output, intent = command_functions[
        np.random.randint(0, len(command_functions), size=1)[0]
    ]()
    inputfile.write(input+"\n")
    outputfile.write(output+"\n")
    labelfile.write(intent+"\n")

inputfile.close()
outputfile.close()
labelfile.close()
